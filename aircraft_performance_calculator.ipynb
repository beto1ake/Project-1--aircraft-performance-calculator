# %%
# Python for aerospace
# NASA pathfinder project - simulation 01
# Goal: Calculate key aircraft performance metrics by user input
import math
print('please enter the values of:')
# Out:
# please enter the values of:
